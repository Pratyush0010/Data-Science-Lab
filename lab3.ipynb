# %% [markdown]
# # Visualization

# %%
import pandas as pb
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Chart

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='dotted')

# add a title
plt.title("Nominal GDP")

# add a label to the x and y-axis
plt.xlabel("Years")
plt.ylabel("Billions of $")
plt.show()

# %%
flight = sns.load_dataset('flights') # load flight dataset
print(flight)

flight_new = flight.groupby('year').sum(numeric_only=True).reset_index()
# line chart
sns.lineplot(x='year',y='passengers',data=flight_new)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# # Bar chart

# %%
# Load dataset
import pandas as pd


# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("./titanic.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# countplot (Survived data) Dataset Titanic
sns.countplot(data=df, x='Sex')
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Bivariate Analysis
sns.barplot(x='Pclass',y='Age',hue='Sex',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # Pie chart

# %%
# pie chart

df['Sex'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # BOX PLOT

# %%
# Boxplot
# 5 number summary
# median , percentile, min=Q1-1.5*IQR, max=Q3+1.5*IQR, IQR = (Q1-Q3), outlier

sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# Bivarient Analysis


#Box plot (Numerical - Categorical)

sns.boxplot(x='Sex',y='Age',hue='Survived',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # Histrogram

# %%
# Numberical Value

# Histogram treat as categorical data distribution of data

plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot
# probability density function --> The line is kde
# skweness
sns.displot(df['Age'], kind="hist", kde=True)

# %%
# Bivariant analysis
sns.kdeplot(df[df['Survived'] == 0]['Age'], label='Died')
sns.kdeplot(df[df['Survived'] == 1]['Age'], label='Survived')

plt.title('Age Distribution by Survival')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# # Scatterplot

# %%
tips = sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# uni to multi-variate analysis
sns.scatterplot(x='total_bill', y='tip',hue='sex', style='smoker',size='size' ,data=tips)
plt.show()

# %% [markdown]
# # Pair plot

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # heat map

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
import seaborn as sns
sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\SHARMA\AppData\Local\Temp\ipykernel_8836\2043977619.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# # Assignment

# %% [markdown]
# ## loading dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)
df=load_dataset("./Health_heart_experimental.csv")
df.head(5)
# Out:
#    Unnamed: 0  age  sex  SysBP  DiaBP   HR  weightKg  heightCm   BMI  \
# 0           0   64    1    141     96  128        69       147  32.0
# 1           1   21    1    109    100  106        48       150  21.0
# 2           2   30    0    112     73  126        69       183  21.0
# 3           3   35    1    106     90  130        45       149  20.0
# 4           4   39    0    140     90  112        92       166  33.0
#
#    indication
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1

# %% [markdown]
# # line chart

# %%
sorted_df = df.sort_values(by='age',ascending=True) #this line is not working
line = df.groupby('age').mean(numeric_only=True).reset_index() #why is here mean bp taken.what should we do if we want to plot real values of bp in the y direction?
plt.figure(figsize=(14, 6))
# line chart
sns.lineplot(x='age',y='SysBP',data=line)
# Out:
# <Axes: xlabel='age', ylabel='SysBP'>

# %% [markdown]
# # Bar plot

# %%
plt.figure(figsize=(14, 6)) 
sns.barplot(x='age',y='HR',hue='sex',data=df)
# Out:
# <Axes: xlabel='age', ylabel='HR'>

# %% [markdown]
# # PIE chart

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(df['SysBP'])
#this box plot shows that the distribution of sysBP from the median is almost uniform with no outliers
# Out:
# <Axes: ylabel='SysBP'>

# %% [markdown]
# # histrogram

# %%
plt.figure(figsize=(20, 6))
plt.hist(df['DiaBP'])
# Out:
# (array([7684., 7825., 6097., 7639., 6106., 7606., 7591., 6023., 7656.,
#         7533.]),
#  array([ 73. ,  77.6,  82.2,  86.8,  91.4,  96. , 100.6, 105.2, 109.8,
#         114.4, 119. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Scatterplot

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='age',y='BMI',hue='sex',data=df)
plt.show()
